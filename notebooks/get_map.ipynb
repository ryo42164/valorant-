# %%
import sys
# !{sys.executable} -m pip install opencv-python easyocr pandas
# Out:
# Requirement already satisfied: opencv-python in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (4.13.0.92)
# Requirement already satisfied: easyocr in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (1.7.2)
# Requirement already satisfied: pandas in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (3.0.1)
# Requirement already satisfied: numpy>=2 in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (from opencv-python) (2.3.5)
# Requirement already satisfied: torch in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (from easyocr) (2.10.0+cu126)
# Requirement already satisfied: torchvision>=0.5 in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (from easyocr) (0.25.0+cu126)
# Requirement already satisfied: opencv-python-headless in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (from easyocr) (4.13.0.92)
# Requirement already satisfied: scipy in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (from easyocr) (1.17.1)
# Requirement already satisfied: Pillow in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (from easyocr) (12.0.0)
# Requirement already satisfied: scikit-image in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (from easyocr) (0.26.0)
# Requirement already satisfied: python-bidi in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (from easyocr) (0.6.7)
# Requirement already satisfied: PyYAML in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (from easyocr) (6.0.3)
# Requirement already satisfied: Shapely in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (from easyocr) (2.1.2)
# Requirement already satisfied: pyclipper in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (from easyocr) (1.4.0)
# Requirement already satisfied: ninja in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (from easyocr) (1.13.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: filelock in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (from torch->easyocr) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (from torch->easyocr) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (from torch->easyocr) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (from torch->easyocr) (3.6.1)
# Requirement already satisfied: jinja2 in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (from torch->easyocr) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (from torch->easyocr) (2025.12.0)
# Requirement already satisfied: setuptools in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (from torch->easyocr) (70.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (from sympy>=1.13.3->torch->easyocr) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (from jinja2->torch->easyocr) (3.0.3)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (from scikit-image->easyocr) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (from scikit-image->easyocr) (2026.3.3)
# Requirement already satisfied: packaging>=21 in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (from scikit-image->easyocr) (26.0)
# Requirement already satisfied: lazy-loader>=0.4 in c:\Users\ryo16\Desktop\dl_practice\.venv\Lib\site-packages (from scikit-image->easyocr) (0.5)

# %%
import re
import cv2
import easyocr
import pandas as pd
from pathlib import Path

# %%
def crop_top_left_banner(frame):
    """
    左上の map / current / decider が表示される帯を切り出す
    返り値: cropped image
    """
    h, w = frame.shape[:2]

    y1 = 0
    y2 = int(h * 0.03) 
    x1 = 0
    x2 = int(w * 0.35)   

    crop = frame[y1:y2, x1:x2]
    return crop

# %%
def preprocess_for_ocr(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    gray = cv2.resize(gray, None, fx=2.0, fy=2.0, interpolation=cv2.INTER_CUBIC)

    _, th = cv2.threshold(gray, 180, 255, cv2.THRESH_BINARY)

    return th

# %%
VALID_MAPS = {
    "ASCENT", "BIND", "SPLIT", "HAVEN", "PEARL",
    "LOTUS", "SUNSET", "ABYSS", "BREEZE", "ICEBOX", "FRACTURE", "CORRODE"
}

def normalize_text(text):
    text = text.upper()
    text = text.replace("|", "I")
    text = text.replace(";", ":")
    text = text.replace(".", ":")
    return text

def extract_current_map(ocr_text):
    """
    OCR文字列から CURRENT: MAPNAME を抜く
    """
    text = normalize_text(ocr_text)

    # まず CURRENT: XXX を探す
    m = re.search(r"CURRENT\s*:\s*([A-Z]+)", text)
    if m:
        cand = m.group(1)
        if cand in VALID_MAPS:
            return cand

    # CURRENT が読めないときでも map名が文中にある場合に拾う緩い版
    for mp in VALID_MAPS:
        if f"CURRENT: {mp}" in text or f"CURRENT {mp}" in text:
            return mp

    return None

# %%
def read_current_map_from_frame(frame, reader):
    crop = crop_top_left_banner(frame)
    proc = preprocess_for_ocr(crop)

    results = reader.readtext(proc, detail=0)
    ocr_text = " ".join(results)

    current_map = extract_current_map(ocr_text)

    return {
        "current_map": current_map,
        "ocr_text": ocr_text,
        "crop": crop,
        "proc": proc
    }

# %%
img_path = Path(r"..\data\samples\bind.png")   
frame = cv2.imread(img_path)

reader = easyocr.Reader(["en"], gpu=False)
result = read_current_map_from_frame(frame, reader)

print("OCR TEXT:", result["ocr_text"])
print("CURRENT MAP:", result["current_map"])
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# OCR TEXT: PEARL 12-14 CURRENT: BIND  DECIDER: SPLIT
# CURRENT MAP: BIND

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 3))
plt.imshow(cv2.cvtColor(result["crop"], cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.title("cropped banner")
plt.show()

plt.figure(figsize=(12, 3))
plt.imshow(result["proc"], cmap="gray")
plt.axis("off")
plt.title("preprocessed for OCR")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 import matplotlib.pyplot as plt
#       3 plt.figure(figsize=(12, 3))
# ----> 4 plt.imshow(cv2.cvtColor(result["crop"], cv2.COLOR_BGR2RGB))
#       5 plt.axis("off")
#       6 plt.title("cropped banner")
#
# NameError: name 'result' is not defined

# %%
def scan_video_current_map(video_path, reader,sample_every_sec=5, max_samples=None):
    cap = cv2.VideoCapture(str(video_path))
    if not cap.isOpened():
        raise ValueError(f"cannot open video: {video_path}")

    fps = cap.get(cv2.CAP_PROP_FPS)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    duration_sec = total_frames / fps


    rows = []
    t = 0.0
    sample_count = 0

    while t < duration_sec:
        frame_idx = int(t * fps)
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame_idx)

        ok, frame = cap.read()
        if not ok:
            t += sample_every_sec
            continue

        result = read_current_map_from_frame(frame, reader)

        rows.append({
            "t_sec": round(t, 2),
            "current_map": result["current_map"],
            "ocr_text": result["ocr_text"]
        })

        sample_count += 1
        if max_samples is not None and sample_count >= max_samples:
            break

        t += sample_every_sec

    cap.release()
    return pd.DataFrame(rows)

# %%
reader = easyocr.Reader(["en"], gpu=True)
video_path = Path("../data/vods/M8 vs. EDG - VALORANT Masters Santiago - SWISS.mp4")
df = scan_video_current_map(video_path=video_path,reader=reader)

# %%
plot_df = df.copy()

plot_df["map_code"] = plot_df["current_map"].astype("category").cat.codes
map_categories = list(plot_df["current_map"].astype("category").cat.categories)

plt.figure(figsize=(14, 4))
plt.scatter(plot_df["t_sec"], plot_df["map_code"], s=8)
plt.yticks(range(len(map_categories)), map_categories)
plt.xlabel("time (sec)")
plt.ylabel("current_map")
plt.title("Detected current_map over time")
plt.show()

# %%
def extract_map_ranges_by_first_last(
    df: pd.DataFrame,
    time_col: str = "t_sec",
    map_col: str = "current_map",
    valid_maps: set[str] = VALID_MAPS,
    max_maps: int = 5,
) -> pd.DataFrame:
    work = df[[time_col, map_col]].copy()
    work = work[work[map_col].isin(valid_maps)].copy()

    if work.empty:
        return pd.DataFrame(columns=[
            "map_no", "map_name", "map_start_sec", "map_end_sec"
        ])

    order = work[map_col].drop_duplicates().tolist()[:max_maps]

    rows = []
    for i, m in enumerate(order, start=1):
        sub = work[work[map_col] == m]
        rows.append({
            "map_no": i,
            "map_name": m,
            "map_start_sec": sub[time_col].min(),
            "map_end_sec": sub[time_col].max(),
        })

    return pd.DataFrame(rows)

# %%
extract_map_ranges_by_first_last(df)
# Out:
#    map_no map_name  map_start_sec  map_end_sec
# 0       1    HAVEN           10.0       3225.0
# 1       2    PEARL         3245.0       5895.0

# %%
df_path = Path("../data/samples/map_df.csv")
df.to_csv(df_path)
