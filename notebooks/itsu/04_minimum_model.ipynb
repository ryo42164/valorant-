# %%
import pandas as pd
import numpy as np
from pathlib import Path
import cv2
import matplotlib.pyplot as plt
# Out:
# 'Python 3.11.9' でセルを実行するには、 ipykernel パッケージが必要です。
#
# 'ipykernel' を Python 環境にインストールします。
#
# コマンド: '/Users/saitou/.pyenv/versions/3.11.9/bin/python -m pip install ipykernel -U --force-reinstall'
